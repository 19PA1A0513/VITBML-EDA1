# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A0513/VITBML-EDA1/blob/master/Copy_of_Copy_of_Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The data is about gun violence:**

# %% [markdown]
# The columns in the given dataset are:

# %%
import pandas as pd
pp=pd.read_csv('gun_violence_data.csv')
pp.columns
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Index(['incident_id', 'date', 'state', 'city_or_county', 'address', 'n_killed',
#        'n_injured', 'incident_url', 'source_url',
#        'incident_url_fields_missing', 'congressional_district', 'gun_stolen',
#        'gun_type', 'incident_characteristics', 'latitude',
#        'location_description', 'longitude', 'n_guns_involved', 'notes',
#        'participant_age', 'participant_age_group', 'participant_gender',
#        'participant_name', 'participant_relationship', 'participant_status',
#        'participant_type', 'sources', 'state_house_district',
#        'state_senate_district'],
#       dtype='object')

# %%
import pandas as pd
pp=pd.read_csv('gun_violence_data.csv')
pp
# Out:
#         incident_id        date  ... state_house_district state_senate_district
# 0            461105  2013-01-01  ...                  NaN                   NaN
# 1            460726  2013-01-01  ...                 62.0                  35.0
# 2            478855  2013-01-01  ...                 56.0                  13.0
# 3            478925  2013-01-05  ...                 40.0                  28.0
# 4            478959  2013-01-07  ...                 62.0                  27.0
# ...             ...         ...  ...                  ...                   ...
# 239672      1083142  2018-03-31  ...                  NaN                   NaN
# 239673      1083139  2018-03-31  ...                 23.0                  31.0
# 239674      1083151  2018-03-31  ...                 85.0                   7.0
# 239675      1082514  2018-03-31  ...                149.0                  17.0
# 239676      1081940  2018-03-31  ...                111.0                   3.0
#
# ...

# %%
import pandas as pd
pp=pd.read_csv('gun_violence_data.csv')
pp
# Out:
#        incident_id        date  ... state_house_district state_senate_district
# 0           461105  2013-01-01  ...                  NaN                   NaN
# 1           460726  2013-01-01  ...                 62.0                  35.0
# 2           478855  2013-01-01  ...                 56.0                  13.0
# 3           478925  2013-01-05  ...                 40.0                  28.0
# 4           478959  2013-01-07  ...                 62.0                  27.0
# ...            ...         ...  ...                  ...                   ...
# 47847       225357  2014-11-27  ...                 50.0                  26.0
# 47848       225787  2014-11-27  ...                  NaN                   NaN
# 47849       225605  2014-11-27  ...                128.0                  53.0
# 47850       226314  2014-11-27  ...                 20.0                  20.0
# 47851       225436  2014-11-27  ...                  NaN                   NaN
#
# ...

# %% [markdown]
# **questions :**
#
# *which state is having more gun violence?*
#
# *Average number of people killed in violence ?*
#
# *Average number of people injured in violence?*
#
# *which incident characterstics has repeated the most?*
#
# *which age group is doing more crime?*
#
# *which gender is particpating in more crime?*
#
# *which state house district is repeated the most?*

# %% [markdown]
# *To acheive our requirements first we have to import th DataFrame in pandas and after that we have to start operations on it by raeding our file in the csv format*

# %%
# some basic operations
import pandas as pd
pp=pd.read_csv('gun_violence_data.csv')
pp.dtypes
# Out:
# incident_id                      int64
# date                            object
# state                           object
# city_or_county                  object
# address                         object
# n_killed                         int64
# n_injured                        int64
# incident_url                    object
# source_url                      object
# incident_url_fields_missing       bool
# congressional_district         float64
# gun_stolen                      object
# gun_type                        object
# incident_characteristics        object
# latitude                       float64
# location_description            object
# longitude                      float64
# n_guns_involved                float64
# notes                           object
# participant_age                 object
# participant_age_group           object
# participant_gender              object
# participant_name                object
# participant_relationship        object
# ...

# %%
#performing centeral tendency operations on data
import pandas as pd
pp=pd.read_csv('gun_violence_data.csv')
pp.mean()
# Out:
# incident_id                    157407.196700
# n_killed                            0.245702
# n_injured                           0.462409
# incident_url_fields_missing         0.000000
# congressional_district              7.980851
# latitude                           37.303199
# longitude                         -88.812715
# n_guns_involved                     1.253400
# state_house_district               54.853945
# state_senate_district              20.248728
# dtype: float64

# %%
pp.mode()
# Out:
#        incident_id        date  ... state_house_district state_senate_district
# 0            92114  2014-09-06  ...                 18.0                   5.0
# 1            92117         NaN  ...                  NaN                   NaN
# 2            92119         NaN  ...                  NaN                   NaN
# 3            92122         NaN  ...                  NaN                   NaN
# 4            92125         NaN  ...                  NaN                   NaN
# ...            ...         ...  ...                  ...                   ...
# 40483      1037694         NaN  ...                  NaN                   NaN
# 40484      1041070         NaN  ...                  NaN                   NaN
# 40485      1049166         NaN  ...                  NaN                   NaN
# 40486      1057043         NaN  ...                  NaN                   NaN
# 40487      1074613         NaN  ...                  NaN                   NaN
#
# ...

# %%
pp.median()
# Out:
# incident_id                    150882.50000
# n_killed                            0.00000
# n_injured                           0.00000
# incident_url_fields_missing         0.00000
# congressional_district              5.00000
# latitude                           38.21455
# longitude                         -85.46595
# n_guns_involved                     1.00000
# state_house_district               47.00000
# state_senate_district              18.00000
# dtype: float64

# %%
pp.count()
# Out:
# incident_id                    40488
# date                           40488
# state                          40488
# city_or_county                 40488
# address                        37020
# n_killed                       40488
# n_injured                      40488
# incident_url                   40488
# source_url                     40467
# incident_url_fields_missing    40488
# congressional_district         40367
# gun_stolen                      3601
# gun_type                        3603
# incident_characteristics       40394
# latitude                       40380
# location_description            1179
# longitude                      40380
# n_guns_involved                 3603
# notes                          26993
# participant_age                22596
# participant_age_group          34834
# participant_gender             35146
# participant_name               18256
# participant_relationship         376
# participant_status             35870
# ...

# %%
pp.max()
# Out:
# incident_id                                                             1074613
# date                                                                 2014-10-06
# state                                                                   Wyoming
# city_or_county                                               Zuni (Zuni Pueblo)
# n_killed                                                                     11
# n_injured                                                                    19
# incident_url                   http://www.gunviolencearchive.org/incident/99999
# incident_url_fields_missing                                               False
# congressional_district                                                       53
# latitude                                                                   71.3
# longitude                                                              -67.7617
# n_guns_involved                                                             151
# ...

# %%
pp.min()
# Out:
# incident_id                                                                92114
# date                                                                  2013-01-01
# state                                                                    Alabama
# city_or_county                                                         Abbeville
# n_killed                                                                       0
# n_injured                                                                      0
# incident_url                   http://www.gunviolencearchive.org/incident/100003
# incident_url_fields_missing                                                False
# congressional_district                                                         1
# latitude                                                                 19.4554
# longitude                                                                -164.62
# n_guns_involved                                                                1
# ...

# %%
pp.shape
# Out:
# (40488, 29)

# %%
pp.ndim
# Out:
# 2

# %%
pp.dtypes
# Out:
# incident_id                      int64
# date                            object
# state                           object
# city_or_county                  object
# address                         object
# n_killed                         int64
# n_injured                        int64
# incident_url                    object
# source_url                      object
# incident_url_fields_missing       bool
# congressional_district         float64
# gun_stolen                      object
# gun_type                        object
# incident_characteristics        object
# latitude                       float64
# location_description            object
# longitude                      float64
# n_guns_involved                float64
# notes                           object
# participant_age                 object
# participant_age_group           object
# participant_gender              object
# participant_name                object
# participant_relationship        object
# ...

# %%
pp.head()
# Out:
#    incident_id        date  ... state_house_district state_senate_district
# 0       461105  2013-01-01  ...                  NaN                   NaN
# 1       460726  2013-01-01  ...                 62.0                  35.0
# 2       478855  2013-01-01  ...                 56.0                  13.0
# 3       478925  2013-01-05  ...                 40.0                  28.0
# 4       478959  2013-01-07  ...                 62.0                  27.0
#
# [5 rows x 29 columns]

# %%
pp.tail()
# Out:
#        incident_id        date  ... state_house_district state_senate_district
# 40483       201605  2014-10-06  ...                 51.0                  23.0
# 40484       202141  2014-10-06  ...                113.0                  42.0
# 40485       202381  2014-10-06  ...                 26.0                  13.0
# 40486       202955  2014-10-06  ...                 86.0                  14.0
# 40487       202020  2014-10-06  ...                  NaN                   NaN
#
# [5 rows x 29 columns]

# %%
pp.head(10)
# Out:
#    incident_id        date  ... state_house_district state_senate_district
# 0       461105  2013-01-01  ...                  NaN                   NaN
# 1       460726  2013-01-01  ...                 62.0                  35.0
# 2       478855  2013-01-01  ...                 56.0                  13.0
# 3       478925  2013-01-05  ...                 40.0                  28.0
# 4       478959  2013-01-07  ...                 62.0                  27.0
# 5       478948  2013-01-07  ...                 72.0                  11.0
# 6       479363  2013-01-19  ...                 10.0                  14.0
# 7       479374  2013-01-21  ...                 93.0                   5.0
# 8       479389  2013-01-21  ...                 11.0                   7.0
# 9       492151  2013-01-23  ...                  NaN                  44.0
#
# [10 rows x 29 columns]

# %%
pp.tail(10)
# Out:
#        incident_id        date  ... state_house_district state_senate_district
# 40478       201428  2014-10-06  ...                 10.0                   4.0
# 40479       202059  2014-10-06  ...                 34.0                  20.0
# 40480       201947  2014-10-06  ...                 44.0                  11.0
# 40481       201603  2014-10-06  ...                104.0                  28.0
# 40482       202346  2014-10-06  ...                 65.0                  33.0
# 40483       201605  2014-10-06  ...                 51.0                  23.0
# 40484       202141  2014-10-06  ...                113.0                  42.0
# 40485       202381  2014-10-06  ...                 26.0                  13.0
# 40486       202955  2014-10-06  ...                 86.0                  14.0
# 40487       202020  2014-10-06  ...                  NaN                   NaN
#
# [10 rows x 29 columns]

# %%
pp.describe()
# Out:
#         incident_id      n_killed  ...  state_house_district  state_senate_district
# count  4.048800e+04  40488.000000  ...          34932.000000           35975.000000
# mean   1.574072e+05      0.245702  ...             54.853945              20.248728
# std    6.377963e+04      0.516379  ...             39.060491              13.922582
# min    9.211400e+04      0.000000  ...              1.000000               1.000000
# 25%    1.215268e+05      0.000000  ...             22.000000               9.000000
# 50%    1.508825e+05      0.000000  ...             47.000000              18.000000
# 75%    1.810942e+05      0.000000  ...             84.000000              30.000000
# max    1.074613e+06     11.000000  ...            217.000000              67.000000
#
# [8 rows x 9 columns]

# %%
pp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40488 entries, 0 to 40487
# Data columns (total 29 columns):
# incident_id                    40488 non-null int64
# date                           40488 non-null object
# state                          40488 non-null object
# city_or_county                 40488 non-null object
# address                        37020 non-null object
# n_killed                       40488 non-null int64
# n_injured                      40488 non-null int64
# incident_url                   40488 non-null object
# source_url                     40467 non-null object
# incident_url_fields_missing    40488 non-null bool
# congressional_district         40367 non-null float64
# gun_stolen                     3601 non-null object
# gun_type                       3603 non-null object
# incident_characteristics       40394 non-null object
# latitude                       40380 non-null float64
# location_description           1179 non-null object
# ...

# %%
pp.describe(include='all')
# Out:
#          incident_id        date  ... state_house_district state_senate_district
# count   4.048800e+04       40488  ...         34932.000000          35975.000000
# unique           NaN         456  ...                  NaN                   NaN
# top              NaN  2014-09-06  ...                  NaN                   NaN
# freq             NaN         220  ...                  NaN                   NaN
# mean    1.574072e+05         NaN  ...            54.853945             20.248728
# std     6.377963e+04         NaN  ...            39.060491             13.922582
# min     9.211400e+04         NaN  ...             1.000000              1.000000
# 25%     1.215268e+05         NaN  ...            22.000000              9.000000
# 50%     1.508825e+05         NaN  ...            47.000000             18.000000
# 75%     1.810942e+05         NaN  ...            84.000000             30.000000
# max     1.074613e+06         NaN  ...           217.000000             67.000000
#
# ...

# %%
pp.dropna()
# Out:
#        incident_id        date  ... state_house_district state_senate_district
# 36          482856  2013-03-13  ...                101.0                  51.0
# 83          486623  2013-05-23  ...                 35.0                   8.0
# 101         487833  2013-06-15  ...                 51.0                  19.0
# 181         492276  2013-08-25  ...                 19.0                   5.0
# 200         480521  2013-09-19  ...                  2.0                   1.0
# 6075        106101  2014-02-12  ...                 73.0                  27.0
# 8564        113439  2014-03-09  ...                 97.0                  30.0
# 8897        114096  2014-03-11  ...                100.0                  15.0
# 9129        114929  2014-03-14  ...                 26.0                   6.0
# 10435       118455  2014-03-24  ...                  4.0                   4.0
# 10907       771623  2014-03-28  ...                 31.0                   9.0
# ...

# %%
pp.fillna(1)
# Out:
#        incident_id        date  ... state_house_district state_senate_district
# 0           461105  2013-01-01  ...                  1.0                   1.0
# 1           460726  2013-01-01  ...                 62.0                  35.0
# 2           478855  2013-01-01  ...                 56.0                  13.0
# 3           478925  2013-01-05  ...                 40.0                  28.0
# 4           478959  2013-01-07  ...                 62.0                  27.0
# ...            ...         ...  ...                  ...                   ...
# 40483       201605  2014-10-06  ...                 51.0                  23.0
# 40484       202141  2014-10-06  ...                113.0                  42.0
# 40485       202381  2014-10-06  ...                 26.0                  13.0
# 40486       202955  2014-10-06  ...                 86.0                  14.0
# 40487       202020  2014-10-06  ...                  1.0                   1.0
#
# ...

# %%
pp.mode()
# Out:
#         incident_id        date  ... state_house_district state_senate_district
# 0             92114  2017-01-01  ...                 18.0                   5.0
# 1             92117         NaN  ...                  NaN                   NaN
# 2             92119         NaN  ...                  NaN                   NaN
# 3             92122         NaN  ...                  NaN                   NaN
# 4             92125         NaN  ...                  NaN                   NaN
# ...             ...         ...  ...                  ...                   ...
# 239672      1083428         NaN  ...                  NaN                   NaN
# 239673      1083435         NaN  ...                  NaN                   NaN
# 239674      1083457         NaN  ...                  NaN                   NaN
# 239675      1083466         NaN  ...                  NaN                   NaN
# 239676      1083472         NaN  ...                  NaN                   NaN
#
# ...

# %%
pp['state'].mode()
# Out:
# 0    Illinois
# dtype: object

# %%
pp['n_killed'].mean()
# Out:
# 0.25228953967214207

# %%
pp['n_injured'].mean()
# Out:
# 0.4940065171042695

# %%
pp['incident_characteristics'].mode()
# Out:
# 0    Shot - Wounded/Injured
# dtype: object

# %%
pp['participant_age_group'].mode()
# Out:
# 0    0::Adult 18+
# dtype: object

# %%
pp['participant_gender'].mode()
# Out:
# 0    0::Male
# dtype: object

# %%
pp['state_house_district'].mode()
# Out:
# 0    18.0
# dtype: float64

# %%
import matplotlib.pyplot as plt
b=pp['n_killed']
c=pp['n_injured']
plt.plot(b,color='g')
plt.plot(c,color='r')
plt.title('line plot')
plt.xlabel('xaxis')
plt.ylabel('yaxis')
plt.show()

# %%
d=pp['state_house_district']
e=pp['state_senate_district']
plt.plot(b,color='yellow')
plt.plot(c,color='orange')
plt.title('line plot')
plt.xlabel('xaxis')
plt.ylabel('yaxis')
plt.show()

# %% [markdown]
# group name=HSMP
#
# roll numbers = 19pa1a0513,
# 19pa1a0553,
# 19pa1a0518,
# 19pa1a0522,
